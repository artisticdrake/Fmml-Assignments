# %% [markdown]
# <a href="https://colab.research.google.com/github/artisticdrake/Fmml-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 12:59:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   193MB/s    in 0.4s
#
# 2023-05-28 12:59:12 (193 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3377 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2681 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 60  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 9  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1759   1511.05392v3  We describe a method for learning word embeddi...  stat
# 7046   1709.05602v1  In many datasets, different parts of the data ...  stat
# 6829   1706.05374v5  We propose expected policy gradients (EPG), wh...  stat
# 10187  1711.03676v1  This work presents an overarching perspective ...    cs
# 22315  1601.00504v1  The aim of this paper is to provide a new meth...  stat
# ...             ...                                                ...   ...
# 22199  1507.05131v4  The density matrices are positively semi-defin...  stat
# 6608   1704.00794v2  Similarity-based approaches represent a promis...  stat
# 2444    1401.3877v1  We address the problem of computing approximat...    cs
# 20815  1703.03693v1  Quantum decision systems are being increasingl...    cs
# 33305   1009.4991v1  Web page categorization is one of the challeng...    cs
#
#                                                    title  year  \
# 1759      Learning the Dimensionality of Word Embeddings  2015
# 7046   Learning Mixtures of Multi-Output Regression M...  2017
# 6829                           Expected Policy Gradients  2017
# 10187        Communicative Capital for Prosthetic Agents  2017
# 22315  Learning relationships between data obtained i...  2016
# ...                                                  ...   ...
# 22199    Optimal Estimation of Low Rank Density Matrices  2015
# 6608   Time Series Cluster Kernel for Learning Simila...  2017
# 2444   Properties of Bethe Free Energies and Message ...  2014
# 20815                          On Quantum Decision Trees  2017
# 33305  Web Page Categorization Using Artificial Neura...  2010
#
#                                                 keywords
# 1759   [embeddings, dependent, dimensionality, stocha...
# 7046   [different, correlation, structure, correlatio...
# 6829   [gradients, stochastic, gradients, determinist...
# 10187  [overarching, perspective, intelligence, enhan...
# 22315  [relationships, independently, technique, cont...
# ...                                                  ...
# 22199  [positively, hermitian, estimation, regression...
# 6608   [similarity, approaches, represent, promising,...
# 2444   [computing, approximate, marginals, probabilis...
# 20815  [increasingly, considered, artificial, intelli...
# 33305  [categorization, challenging, increasing, tech...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1759     [embeddings, dependent, dimensionality, stocha...
# 7046     [different, correlation, structure, correlatio...
# 6829     [gradients, stochastic, gradients, determinist...
# 10187    [overarching, perspective, intelligence, enhan...
# 22315    [relationships, independently, technique, cont...
#                                ...
# 35535    [approaches, combination, ontologies, classica...
# 6540     [stochastic, approximating, stochastic, approx...
# 3129     [appropriately, principled, dimensional, struc...
# 4313     [randomized, principal, component, employing, ...
# 6710     [stochastic, nonconvex, optimization, approxim...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8726 words.
# Out of those 4544 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="53aa288f-cb8b-403e-b832-30a7add7aa98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53aa288f-cb8b-403e-b832-30a7add7aa98")) {                    Plotly.newPlot(                        "53aa288f-cb8b-403e-b832-30a7add7aa98",                        [{"x":["dependent","competitive","distribution","techniques","embeddings","providing","dimension","continuous","counterparts","embedding","employing","dimensions","qualitatively","stochastic","distribute","quantitatively","nonparametric","semantics","dimensionalities","dimensionality","different","relationship","structure","correlation","canonical","synthetic","clustering","regression","interpreted","variations","interpretation","demonstrated","deterministic","trajectory","empirical","requiring","challenging","estimates","computational","outperforms","exponential","reinforcement","exploration","proportional","heuristic","substantially","integrates","uhlenbeck","establish","covariance","confirming","estimating","gradients","interpreting","available","hypothesis","conventional","artificial","enhancing","abilities","increasing","progression","enhancements","literature","intelligence","collaboration","developed","viewpoint","prosthetic","effectively","technology","generation","communicative","sensorimotor","significantly","communication","diminished","disadvantages","functional","concretely","introduce","technologies","increased","especially","interaction","contribution","resources","overarching","interactions","assistive","perspective","specifically","increasingly","information","theoretical","described","technique","relationships","deconvolution","dependency","variables","validation","contextual","advantages","therefore","independently","competing","precisely","achieving","prediction","determined","promising","partially","downsampling","classifiers","exploring","improvement","convolutional","simultaneously","performance","preservation","resolution","localization","operation","significant","predictions","important","deconvolutional","experiment","granularity","boundaries","observation","demonstrate","frequency","deficient","multiplier","motivated","extending","distributions","existence","structured","experimental","factorized","underlying","statistics","corresponds","associated","alternating","smoothness","algorithm","inpainting","decomposition","algorithms","direction","components","corrupted","insignificant","discriminant","researches","assumption","appealing","classification","preceding","simulated","motivation","asymptotic","scenarios","recommended","attention","advantage","individually","estimator","properties","capability","correlations","recognition","logarithm","individual","objective","likelihoods","alignments","posteriors","calibration","sensitive","probabilistic","principle","automatic","independent","calibrated","similarly","ensembles","increases","inference","generalized","possibility","interpretability","predictive","statistical","description","illustrate"],"y":[75,105,224,365,80,78,65,117,20,102,38,32,23,122,3,22,14,100,1,63,775,78,323,76,19,145,155,106,17,87,66,108,36,34,150,43,282,73,299,263,50,106,48,14,65,40,30,1,47,22,1,61,36,15,290,42,108,152,25,15,103,5,9,143,102,15,218,23,1,109,41,143,4,2,270,55,1,10,41,1,304,35,46,141,81,78,70,3,76,2,61,160,58,724,154,58,234,72,11,39,124,46,42,98,147,40,27,30,75,221,32,117,44,3,113,44,164,376,129,854,8,105,69,34,231,77,381,4,87,12,37,66,579,53,4,5,68,25,120,26,109,388,7,125,62,20,114,20,23,856,8,62,594,51,99,19,3,12,6,65,20,500,4,69,20,20,94,4,179,89,15,26,185,48,26,360,2,123,175,6,9,3,20,61,147,50,175,116,11,23,14,56,210,77,33,17,44,155,57,62],"type":"bar"},{"x":["dependent","competitive","distribution","techniques","embeddings","provi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4544,), (4544, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fully</span> <span style='background-color:rgba(0, 255, 0, 0.6347826086956521);'>Convolutional</span> <span style=''>Grasp</span> <span style='background-color:rgba(0, 255, 0, 0.5513626834381551);'>Detection</span> <span style=''>Network</span> <span style=''>with</span> <span style=''>Oriented</span> <span style=''>Anchor</span> <span style=''>Box</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>multiple</span> <span style=''>grasping</span> <span style=''>poses</span> <span style=''>for</span> <span style=''>a</span> <span style=''>parallel</span> <span style=''>plate</span> <span style=''>robotic</span> <span style=''>gripper</span> <span style=''>using</span> <span style=''>RGB</span> <span style=''>images</span> <span style=''>A</span> <span style=''>model</span> <span style=''>with</span> <span style=''>oriented</span> <span style=''>anchor</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.4736842105263159);'>mechanism</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>and</span> <span style=''>a</span> <span style=''>new</span> <span style=''>matching</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>used</span> <span style=''>during</span> <span style=''>the</span> <span style=''>training</span> <span style=''>process</span> <span style=''>An</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.6347826086956521);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>is</span> <span style=''>employed</span> <span style=''>in</span> <span style=''>our</span> <span style=''>work</span> <span style=''>The</span> <span style=''>network</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>two</span> <span style=''>parts</span> <span style=''>the</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>extractor</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>grasp</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>predictor</span> <span style=''>The</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>extractor</span> <span style=''>is</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.6347826086956521);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>The</span> <span style=''>multi</span> <span style=''>grasp</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153846);'>predictor</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>regresses</span> <span style=''>grasp</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>rectangles</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predefined</span> <span style=''>oriented</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>rectangles</span> <span style=''>called</span> <span style=''>oriented</span> <span style=''>anchor</span> <span style=''>boxes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>classifies</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>rectangles</span> <span style=''>into</span> <span style=''>graspable</span> <span style=''>and</span> <span style=''>ungraspable</span> <span style=''>On</span> <span style=''>the</span> <span style=''>standard</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradient</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exponential</span> <span style=''>Families</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(KMC)</span> <span style=''>a</span> <span style=''>gradient</span> <span style=''>free</span> <span style=''>adaptive</span> <span style=''>MCMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(HMC)</span> <span style=''>On</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>densities</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style=''>HMC</span> <span style=''>is</span> <span style=''>not</span> <span style=''>an</span> <span style=''>option</span> <span style=''>due</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>gradients</span> <span style=''>KMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adaptively</span> <span style=''>learns</span> <span style=''>the</span> <span style=''>targets</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>by</span> <span style=''>fitting</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>model</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style=''>costs</span> <span style=''>are</span> <span style=''>reduced</span> <span style=''>by</span> <span style=''>two</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>to</span> <span style=''>this</span> <span style=''>gradient</span> <span style=''>While</span> <span style=''>being</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotically</span> <span style=''>exact</span> <span style=''>KMC</span> <span style=''>mimics</span> <span style=''>HMC</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiency</span> <span style=''>and</span> <span style=''>offers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>substantial</span> <span style=''>mixing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>over</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>gradient</span> <span style=''>free</span> <span style=''>samplers</span> <span style=''>We</span> <span style=''>support</span> <span style=''>our</span> <span style=''>claims</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>studies</span> <span style=''>on</span> <span style=''>both</span> <span style=''>toy</span> <span style=''>an ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(255, 0, 0, 0.48571428571428577);'>Coordinate</span> <span style=''>Descent</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>arises</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>The</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>solvable</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>but</span> <span style=''>general</span> <span style=''>purpose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>high</span> <span style=''>running</span> <span style=''>times</span> <span style=''>and</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsuitable</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>have</span> <span style=''>used</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>very</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>sums</span> <span style=''>of</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>use</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.48571428571428577);'>coordinate</span> <span style=''>descent</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>with</span> <span style=''>faster</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3011363636363636);'>convergence</span> <span style=''>rates</span> <span style=''>and</span> <span style=''>cheaper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>costs</span> <span style=''>Compared</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.37500000000000006);'>alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>methods</span> <span style=''>our</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <span style=''>and</span> <span style=''>learning</span> <span style=''>over</span> <span style=''>networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>system</span> <span style=''>modeling</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>chapter</span> <span style=''>we</span> <span style=''>analyze</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>problems</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environments</span> <span style=''>eg</span> <span style=''>sensor</span> <span style=''>networks</span> <span style=''>or</span> <span style=''>peer</span> <span style=''>to</span> <span style=''>peer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>protocols</span> <span style=''>In</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scenarios</span> <span style=''>the</span> <span style=''>agents</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>receive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>fashion</span> <span style=''>and</span> <span style=''>they</span> <span style=''>are</span> <span style=''>required</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>a</span> <span style=''>common</span> <span style=''>(nonlinear)</span> <span style=''>model</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>communications</span> <span style=''>with</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighbors</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinction</span> <span style=''>between</span> <span style=''>single</span> <span style=''>task</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>model</span> <span style=''>is</span> <span style=''>common</span> <span style=''>to</span> <span style=''>all</span> <span style=''>agents</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>each</span> <span style=''>agent</span> <span style=''>might</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>model</span> <span style=''>due</span> <span style=''>to</span> <span style=''>eg</span> <span style=''>spatial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>or</span> <span style=''>other</span> <span style=''>factors</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Currently</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span sty ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08430335097001763)
# 	processing (0.1037037037037037)
# 	challenging (0.09947089947089947)
# 	knowledge (0.12663139329805997)
# 	segmentation (0.07936507936507936)
# 	information (0.255379188712522)
# 	different (0.27336860670194)
# 	detection (0.13051146384479717)
# 	recognition (0.12698412698412698)
# 	convolutional (0.1326278659611993)
#
# Some Statistics words are:
# 	algorithm (0.3933842239185751)
# 	stochastic (0.13638676844783715)
# 	variables (0.13944020356234096)
# 	distribution (0.178117048346056)
# 	theoretical (0.15368956743002546)
# 	statistical (0.15470737913486005)
# 	estimation (0.17709923664122137)
# 	dimensional (0.1826972010178117)
# 	inference (0.1984732824427481)
# 	regression (0.1826972010178117)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="2164f09d-e4dd-4cc5-892e-997774cd5631" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2164f09d-e4dd-4cc5-892e-997774cd5631")) {                    Plotly.newPlot(                        "2164f09d-e4dd-4cc5-892e-997774cd5631",                        [{"x":["dependent","competitive","distribution","techniques","embeddings","providing","dimension","continuous","counterparts","embedding","employing","dimensions","qualitatively","stochastic","distribute","quantitatively","nonparametric","semantics","dimensionalities","dimensionality","different","relationship","structure","correlation","canonical","synthetic","clustering","regression","interpreted","variations","interpretation","demonstrated","deterministic","trajectory","empirical","requiring","challenging","estimates","computational","outperforms","exponential","reinforcement","exploration","proportional","heuristic","substantially","integrates","uhlenbeck","establish","covariance","confirming","estimating","gradients","interpreting","available","hypothesis","conventional","artificial","enhancing","abilities","increasing","progression","enhancements","literature","intelligence","collaboration","developed","viewpoint","prosthetic","effectively","technology","generation","communicative","sensorimotor","significantly","communication","diminished","disadvantages","functional","concretely","introduce","technologies","increased","especially","interaction","contribution","resources","overarching","interactions","assistive","perspective","specifically","increasingly","information","theoretical","described","technique","relationships","deconvolution","dependency","variables","validation","contextual","advantages","therefore","independently","competing","precisely","achieving","prediction","determined","promising","partially","downsampling","classifiers","exploring","improvement","convolutional","simultaneously","performance","preservation","resolution","localization","operation","significant","predictions","important","deconvolutional","experiment","granularity","boundaries","observation","demonstrate","frequency","deficient","multiplier","motivated","extending","distributions","existence","structured","experimental","factorized","underlying","statistics","corresponds","associated","alternating","smoothness","algorithm","inpainting","decomposition","algorithms","direction","components","corrupted","insignificant","discriminant","researches","assumption","appealing","classification","preceding","simulated","motivation","asymptotic","scenarios","recommended","attention","advantage","individually","estimator","properties","capability","correlations","recognition","logarithm","individual","objective","likelihoods","alignments","posteriors","calibration","sensitive","probabilistic","principle","automatic","independent","calibrated","similarly","ensembles","increases","inference","generalized","possibility","interpretability","predictive","statistical","description","illustrate","compression","compactly","completely","parameterized","tractable","polynomial","decomposable","parameters","parameter","analytically","constrain","formulate","observations","likelihood","integrated","assumptions","structures","posterior","dirichlet","inequalities","applications","sparsification","concerning","completion","perturbation","iterative","segmentation","difficulties","application","intelligent","cancerous","physicians","sensitivity","detection","considered","superpixel","reviewing","endoscopy","classified","extracting","evaluated","challenge","superpixels","relatively","examination","comparisons","maintaining","complexes","automated","characteristic","identification","magnitude","additional","efficient","comparing"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	continual
# 	diameters
# 	interfacing
# 	reversible
# 	tractography
# 	tractographies
# 	counterfactuals
# 	duplicate
# 	unbalanced
# 	parsimony
# 	transferability
# 	heteroskedastic
# 	overtraining
# 	blockmodel
# 	negativity
# 	itinerary
# 	factorize
# 	parallelizes
# 	amortised
# 	maximising
# Some words which never appear in Statistics papers:
# 	communicative
# 	sensorimotor
# 	assistive
# 	downsampling
# 	superpixel
# 	endoscopy
# 	superpixels
# 	bilingual
# 	keystroke
# 	panoramic
# 	unaccounted
# 	abstracted
# 	abstracting
# 	derivable
# 	primitive
# 	progressed
# 	metaheuristic
# 	processor
# 	reachability
# 	concludes

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0400680975253848e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7366666666666667
